# %%
import pandas as pd

# %%
pd.read_csv("feed.csv")
# Out:
#                                                 Author  \
# 0    <span class="authorOrTitle">\n    Marilyn Monr...
# 1    <span class="authorOrTitle">\n    Oscar Wilde\...
# 2    <span class="authorOrTitle">\n    Albert Einst...
# 3    <span class="authorOrTitle">\n    Frank Zappa\...
# 4    <span class="authorOrTitle">\n    Marcus Tulli...
# ..                                                 ...
# 205  <span class="authorOrTitle">\n    Oscar Wilde,...
# 206  <span class="authorOrTitle">\n    J.K. Rowling...
# 207  <span class="authorOrTitle">\n    C.S. Lewis\n...
# 208  <span class="authorOrTitle">\n    Sylvia Plath...
# 209  <span class="authorOrTitle">\n    Mark Twain\n...
#
#                                                   Tags  \
# 0    <a href="/quotes/tag/attributed-no-source">att...
# 1    <a href="/quotes/tag/attributed-no-source">att...
# 2    <a href="/quotes/tag/attributed-no-source">att...
# 3    <a href="/quotes/tag/books">books</a>,<a href=...
# ...
